# %% [markdown]
# # 🗒️LISTAS
#
# Sirven para ordenar varios datos y se utilizan los corchetes y cada valor lo separamos por una coma.
#
# __[__ __Dato1, Dato2,...__  __]__

# %%
# Lista normal
# Lista de enteros
lista_de_numeros = [1, 2, 3, 4, 5]
print("Tu lista de numeros son:",lista_de_numeros)

#Lista mixta
##Una lista puede contener diferentes tipos de datos
#Por ejemplo, una lista puede contener enteros, cadenas de texto, booleanos, etc.
lista_mixta = [1, "Hola", 3.14, True]
print("Tu lista mixta es:",lista_mixta)

#Lista vacia
#Una lista vacia es una lista que no contiene ningun elemento
lista_vacia = []
print("Tu lista vacia es:",lista_vacia)

#Lista de String
#Una cadena de texto es un listado de caracteres. Por lo tanto, una lista de String es una lista que contiene solo cadenas de texto.
lista_string = "Hola, Mundo"
print("Tu lista de String es:", lista_string)

#METODOS
#Los metodos son funciones que se aplican a un objeto. En este caso, los metodos se aplican a una lista.

#LEN
#Devuelve el numero de elementos en una lista.
print("Tu lista de numeros tiene ",len(numeros),"elementos.")

#APPEND
#Agregar un elemento al final de una lista
lista_de_numeros.append(6)
print("Tu lista de numeros ahora es:", lista_de_numeros)

#EXTEND
#Agregar varios elementos al final de una lista
#O agregar una lista a otra lista
lista_de_numeros.extend([7, 8, 9])
print("Tu lista de numeros ahora es:", lista_de_numeros)

#INSERT
#Agregar un elemento una lista. Indicando la posición donde se va a agregar el elemento.
#En este caso, se agrega el elemento 0 en la posición 1 de la lista.
#Las posiciones de una lista empiezan desde 0, por lo que la posición 1 es el segundo elemento de la lista.
#Si la posición no existe, se agrega al final de la lista.
#Si la posición es negativa, se cuenta desde el final de la lista.
lista_de_numeros.insert(9, 10)
print("Tu lista de numeros ahora es:", lista_de_numeros)

#POP
#Eliminar el último elemento de una lista
#El método pop elimina el último elemento de una lista y lo devuelve.
#Si se quiere eliminar un elemento en una posición específica, se puede indicar la posición como argumento.
#Si la posición no existe o está vacía, se genera un error.
#El elemento eliminado se puede almacenar en una variable para poder utilizarlo más adelante. (Es opcional)
ultimo_elemento = lista_de_numeros.pop()
print("El último elemento eliminado es:", ultimo_elemento)
print("Tu lista de numeros ahora es:", lista_de_numeros)

#LIST
#Para ver una posición específica de una lista, se puede utilizar el índice de la posición.
print("El primer elemento de la lista es:", lista_de_numeros[0])
print("El segundo elemento de la lista es:", lista_de_numeros[1])

#INDEX
#Para ver una posición específica de una lista, se puede utilizar el índice de la posición.
#El método index devuelve el índice del primer elemento que coincide con el valor indicado.
#Si el valor no se encuentra en la lista, se genera un error.
print("El índice del elemento 3 es:", lista_de_numeros.index(3))
print("El índice del elemento 9 es:", lista_de_numeros.index(9))

#MAX
#El elemento más grande de una lista
print("El elemento más grande de la lista es:", max(lista_de_numeros))

#MIN
#El elemento más pequeño de una lista
print("El elemento más pequeño de la lista es:", min(lista_de_numeros))

#COUNT
#Contar el número de veces que un elemento aparece en una lista
#El método count devuelve el número de veces que un elemento aparece en una lista.
print("El número de veces que el elemento 3 aparece en la lista es:", lista_de_numeros.count(3))

#IN
#Verificar si un elemento está en una lista
#El método in devuelve True si el elemento está en la lista, False en caso contrario.
print("El elemento 3 está en la lista:", 3 in lista_de_numeros)
print("El elemento 10 está en la lista:", 10 in lista_de_numeros)

#REVERSE
#Invertir el orden de los elementos en una lista
#El método reverse invierte el orden de los elementos en una lista.
lista_de_numeros.reverse()
print("Tu lista de numeros despues de REVERSE es:", lista_de_numeros)

# SORT
# Ordenar los elementos de una lista
# El método sort ordena los elementos de una lista en orden ascendente.
lista_de_numeros.sort()
print("Tu lista de numeros despues de SORT es:", lista_de_numeros)

#VALUEERROR
#Error si el elemento no existe
#Si se intenta acceder a un elemento que no existe en la lista, se genera un error
#Por ejemplo, si se intenta acceder o eliminar la posición 10 de una lista que tiene solo 5 elementos, se genera un error.#Esto también ocurre si se intenta eliminar un elemento que no existe en la lista.
print("Intentando acceder a un elemento que no existe en la lista:")
#TRY
#El bloque try permite manejar errores de forma controlada.
#Si se genera un error, se ejecuta el bloque except.
#En este caso, se intenta acceder a un elemento que no existe en la lista.
#Si se genera un error, se imprime un mensaje de error.
#Siendo e un objeto que contiene información sobre el error.
#El error generado es del tipo IndexError. Indica que se está intentando acceder a un índice que no existe en la lista.
try:
    print(lista_de_numeros[10])
except IndexError as e:
    print("Error:", e)


#REMOVE
#Eliminar un elemento de una lista por su valor
#El método remove elimina el primer elemento que coincide con el valor indicado.
lista_de_numeros.remove(4)
print("Tu lista de numeros despues de REMOVE es:", lista_de_numeros)

#DEL - Eliminar un elemento de una lista por su índice
#Eliminar un elemento de una lista por su índice
del lista_de_numeros[2]
print("Tu lista de numeros despues de DEL es:", lista_de_numeros)
#El método del elimina el elemento en la posición indicada.
#Si la posición no existe, se genera un error.
#En este caso, se elimina el tercer elemento de la lista (índice 2).
#Si se intenta eliminar un elemento que no existe en la lista, se genera un error.

#CLEAR
#Eliminar todos los elementos de una lista
#El método clear elimina todos los elementos de una lista.
lista_de_numeros.clear()
print("Tu lista de numeros despues de CLEAR es:", lista_de_numeros)

# COPY
# Crear una copia de una lista
# El método copy crea una copia de una lista.
lista_de_numeros = [1, 2, 3, 4, 5]
copia_lista = lista_de_numeros.copy()
print("Tu lista de numeros es:", lista_de_numeros)
print("Tu copia de la lista de numeros es:", copia_lista)

#DEL - Eliminar una lista
#Eliminar una lista
#El método del elimina una lista.
del lista_de_numeros
try:
    print("Tu lista de numeros es:", lista_de_numeros)
except NameError as e:
    print("Error:", e)

# %% [markdown]
# # 🗒️➡️🗒️Compiando listas
#
# Las listas no se pueden copiar tan simples como una variable.

# %%
#Ejemplo

a = 1
b = a
print("a:", a)
print("b:", b)
#En este caso, a y b son dos variables diferentes que apuntan al mismo valor.
#Si se cambia el valor de a, b no se ve afectado.
a = 2
print("a:", a)
print("b:", b)
#En este caso, a y b siguen siendo dos variables diferentes que apuntan a valores diferentes
#Si se cambia el valor de b, a no se ve afectado.

# %% [markdown]
# Para copiar listas, recurrimos al metodo COPY

# %%
lista_a = [1, 2, 3]
lista_b = lista_a
print("lista_a:", lista_a)
print("lista_b:", lista_b)
#En este caso, lista_a y lista_b son dos variables diferentes que apuntan a la misma lista.
#Si se cambia el valor de lista_a, lista_b también se ve afectada
lista_a[0] = 4
print("lista_a:", lista_a)
print("lista_b:", lista_b)
#En este caso, lista_a y lista_b siguen siendo dos variables diferentes que apuntan a la misma lista.
#Si se cambia el valor de lista_b, lista_a también se ve afectada
lista_b[1] = 5
print("lista_a:", lista_a)
print("lista_b:", lista_b)
#En este caso, lista_a y lista_b siguen siendo dos variables diferentes que apuntan a la misma lista.
#Si se cambia el valor de lista_a, lista_b también se ve afectada

#Para evitar este comportamiento, se puede utilizar el método copy para crear una copia de la lista.
lista_c = lista_a.copy()
print("lista_a:", lista_a)
print("lista_b:", lista_b)
print("lista_c:", lista_c)
#En este caso, lista_a y lista_b siguen siendo dos variables diferentes que apuntan a la misma lista.
#Pero lista_c es una copia de lista_a, por lo que no se ve afectada por los cambios en lista_a o lista_b.
lista_a[2] = 6
print("lista_a:", lista_a)
print("lista_b:", lista_b)
print("lista_c:", lista_c)
#En este caso, lista_a y lista_b siguen siendo dos variables diferentes que apuntan a la misma lista.
#Pero lista_c es una copia de lista_a, por lo que no se ve afectada por los cambios en lista_a o lista_b.
#Si se cambia el valor de lista_c, lista_a y lista_b no se ven afectadas.
lista_c[0] = 7
print("lista_a:", lista_a)
print("lista_b:", lista_b)
print("lista_c:", lista_c)
#En este caso, lista_a y lista_b siguen siendo dos variables diferentes que apuntan a la misma lista.
#Pero lista_c es una copia de lista_a, por lo que no se ve afectada por los cambios en lista_a o lista_b.
#Si se cambia el valor de lista_c, lista_a y lista_b no se ven afectadas.
#Esto es útil cuando se quiere trabajar con una copia de una lista sin afectar a la original.
#Por ejemplo, si se quiere ordenar una lista sin afectar a la original, se puede utilizar el método copy para crear una copia
#de la lista y luego ordenar la copia.

#Tambien se puede utilizar el metodo SLICING para crear una copia de una lista.
lista_d = lista_a[:]
print("lista_a:", lista_a)
print("lista_b:", lista_b)
print("lista_c:", lista_c)
print("lista_d:", lista_d)
#En este caso, lista_d es una copia de lista_a, por lo que no se
#ve afectada por los cambios en lista_a o lista_b.

#Tambien se puede utilizar el metodo LIST para crear una copia de una lista.
lista_e = list(lista_a)
print("lista_a:", lista_a)
print("lista_b:", lista_b)
print("lista_c:", lista_c)
print("lista_d:", lista_d)
print("lista_e:", lista_e)
#En este caso, lista_e es una copia de lista_a, por lo que no se
#ve afectada por los cambios en lista_a o lista_b.
# Out:
# lista_a: [1, 2, 3]
# lista_b: [1, 2, 3]
# lista_a: [4, 2, 3]
# lista_b: [4, 2, 3]
# lista_a: [4, 5, 3]
# lista_b: [4, 5, 3]
# lista_a: [4, 5, 3]
# lista_b: [4, 5, 3]
# lista_c: [4, 5, 3]
# lista_a: [4, 5, 6]
# lista_b: [4, 5, 6]
# lista_c: [4, 5, 3]
# lista_a: [4, 5, 6]
# lista_b: [4, 5, 6]
# lista_c: [7, 5, 3]
# lista_a: [4, 5, 6]
# lista_b: [4, 5, 6]
# lista_c: [7, 5, 3]
# lista_d: [4, 5, 6]
