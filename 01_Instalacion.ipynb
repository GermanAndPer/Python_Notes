# %% [markdown]
# # ⬇️ Instalacion
#
# Para instalar el programa se puede hacer descargando instalando el programa directamente del siguiente Link:
#
# https://www.python.org/doc/
#
# https://www.python.org/downloads/
#
# Para mi caso, ya esta instalado en conda.
#
# Por lo que usaré esa control de versiones para usar desarollar proyectos.
#
# De igual manera, es caso de hacerse la instalacion manual, una vez terminada, se puede acceder a cualquier linea de comandos.
#
# Terminal o CMD:
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
#
# Y escribir el siguiente comando:

# %%
# !python

# %% [markdown]
# Lo que nos dará la version utilizada y un cuadro de Dialogo para empezar a escribir en Python.
#
# ![image.png](attachment:image.png)
#
# Y se podra empezar a escribir cualquier codigo como prueba.
#
# ## 💻 CONSOLA
#
# Desde la consola podemos escribir y evaluar varias funciones. Directamente pueden ser textos. Por ejemplo:

# %%
print("Hello World")

# %% [markdown]
# ![image.png](attachment:image.png)
#
# O opereaciones matematicas:

# %%
5 + 5
5 * 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 🐍 Archivos Python
#
# Los archivos de python tienen la terminacion .PY
